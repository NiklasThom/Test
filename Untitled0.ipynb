# %% [markdown]
# <a href="https://colab.research.google.com/github/NiklasThom/Test/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage to scrape
url = 'https://www.fupa.net/player/stephan-kumpfmueller-552043'

# Send a GET request to the webpage
response = requests.get(url)
response.raise_for_status()  # Check for request errors

# Parse the webpage content
soup = BeautifulSoup(response.text, 'html.parser')

# Print the parsed HTML (for inspection)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="de">
#  <head>
#   <meta charset="utf-8"/>
#   <title data-rh="true">
#    Stephan Kumpfmüller - FC Grünthal - FuPa
#   </title>
#   <meta content='Stephan Kumpfmüller ➤ Spitzname "Kumpf " ➤ FC Grünthal ➤ Kreisliga Inn/Salzach 1️ ➤ 26 Jahre ➤ Torwart ➤ 🎽 137 Spiele ⚽ 0 Tore ⭐ 1 Vorlagen' data-rh="true" name="description">
#    <meta content="index, follow" data-rh="true" name="robots"/>
#    <meta content="Stephan Kumpfmüller - FC Grünthal - FuPa" data-rh="true" property="og:title"/>
#    <meta content='Stephan Kumpfmüller ➤ Spitzname "Kumpf " ➤ FC Grünthal ➤ Kreisliga Inn/Salzach 1️ ➤ 26 Jahre ➤ Torwart ➤ 🎽 137 Spiele ⚽ 0 Tore ⭐ 1 Vorlagen' data-rh="true" property="og:description"/>
#    <meta content="https://www.fupa.net/player/stephan-kumpfmueller-552043" data-rh="true" property="og:url"/>
#    <meta content="profile" data-rh="true" property="og:type"/>
#    <meta content="de_DE" data-rh="true" property="og:locale"/>
# ...

# %%
name_tag = soup.find('h1', class_='Spiele')  # Replace 'player-name' with the actual class
player_name = name_tag.get_text(strip=True) if name_tag else 'N/A'

# Extract player position
position_tag = soup.find('div', class_='player-position')  # Replace 'player-position' with the actual class
player_position = position_tag.get_text(strip=True) if position_tag else 'N/A'

# Print extracted data
print(f"Player Name: {player_name}")
print(f"Position: {player_position}")
# Out:
# Player Name: N/A
# Position: N/A

# %%
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-12-1b9e05c7b9bd> in <cell line: 16>()
#      14 # Initialize the WebDriver
#      15 service = Service(ChromeDriverManager().install())
# ---> 16 driver = webdriver.Chrome(service=service, options=chrome_options)
#      17
#      18 # Navigate to the webpage
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      64
#      65         try:
# ...

# %%
# Extract the player's name
name_tag = soup.find('h1', class_='player-name')  # Update with the correct tag and class
player_name = name_tag.get_text(strip=True) if name_tag else 'N/A'

# Extract the player's position
position_tag = soup.find('div', class_='player-position')  # Update with the correct tag and class
player_position = position_tag.get_text(strip=True) if position_tag else 'N/A'

print(f'Player Name: {player_name}')
print(f'Position: {player_position}')
# Out:
# Player Name: N/A
# Position: N/A
